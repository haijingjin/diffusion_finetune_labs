# %%
# !git clone https://github.com/huggingface/diffusers.git
# %cd diffusers

# %%
# !pip install -r examples/dreambooth/requirements.txt
# !pip install -e .
# !pip install bitsandbytes

# %%
# !accelerate config default

# %%
import os

os.environ["MODEL_NAME"] = "runwayml/stable-diffusion-v1-5"
os.environ["INSTANCE_DIR"] = "/content/drive/MyDrive/hg_imGen/finetuning_input/goph"
os.environ["OUTPUT_DIR"] = "/content/drive/MyDrive/hg_imGen/LoRA_fine_tuned_model"

# %%
# !accelerate launch /content/diffusers/examples/dreambooth/train_dreambooth_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="hj_goph style" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=500 \
  --checkpointing_steps=100 \
  --validation_prompt="hj_goph style" \
  --validation_epochs=50 \
  --seed=0
