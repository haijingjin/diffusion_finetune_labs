# %%
# !git clone https://github.com/huggingface/diffusers
# %cd diffusers
# !pip install -r examples/dreambooth/requirements.txt
# !pip install -e .
# !pip install bitsandbytes

# %%
# !accelerate launch /content/diffusers/examples/dreambooth/train_dreambooth.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5"  \
  --instance_data_dir="/content/drive/MyDrive/hg_imGen/pretraining_input/fox_illustration"  \
  --output_dir="/content/drive/MyDrive/hg_imGen/pretraining_output" \
  --instance_prompt="a photo of a [sks_hj] fox"\
  --class_prompt="a photo of a fox" \
  --with_prior_preservation --num_class_images=20 \
  --class_data_dir="/content/drive/MyDrive/hg_imGen/dreambooth_class_images" \
  --resolution=512 --train_batch_size=1 --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 --lr_scheduler="constant" --lr_warmup_steps=0 \
  --max_train_steps=800 --train_text_encoder \
  --mixed_precision="fp16" --use_8bit_adam
